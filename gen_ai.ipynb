# %%
import google.generativeai


system_message = "You are a helpful assisstant"
user_prompt = "Explain cloud "

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-2.0-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# Okay, let's break down what "the cloud" means in a simple and understandable way.
#
# **What is the Cloud?**
#
# Imagine you have a computer.  All your files, programs, and data are stored directly on that computer's hard drive.  "The cloud" is essentially a network of *other* computers (servers) owned and maintained by companies (like Amazon, Google, Microsoft, etc.) that you can access over the internet.  Instead of storing and running everything on your own computer, you're using their computers to store files, run applications, process data, and more.
#
# **Think of it like this:**
#
# *   **Traditional:** You own a filing cabinet in your house. All your important documents are stored there. You're responsible for its security, maintenance, and space limitations.
# *   **Cloud:** You rent space in a secure, off-site storage facility. They handle the security, maintenance, and you can rent more space as needed. You access your documents through the internet.
#
# **Key Concepts:**
#
# *   **Servers:**  Powerful computers in data centers that store and process information.
# *   **Data Centers:**  Physical buildings filled with servers.
# *   **Internet Connection:** You need an internet connection to access cloud services.
# *   **Pay-as-you-go:**  Often, you only pay for the resources you actually use.
# *   **Scalability:** You can easily increase or decrease the amount of resources you use (storage, processing power) as your needs change.
#
# **What Can You Do With the Cloud?**
#
# The cloud is used for a wide variety of things:
#
# *   **Storage:**  Storing files (photos, documents, videos) online, like with Google Drive, Dropbox, or iCloud.
# *   **Backup and Recovery:**  Automatically backing up your data to the cloud so you can recover it if your computer crashes.
# *   **Software as a Service (SaaS):** Using applications over the internet, like Gmail, Salesforce, or Microsoft Office 365.  You don't install the software on your computer; you just access it online.
# *   **Platform as a Service (PaaS):** Providing a platform for developers to build and run applications without managing the underlying infrastructure (servers, networks, etc.).
# *   **Infrastructure as a Service (IaaS):** Providing virtualized computing resources (servers, storage, networks) over the internet.  You manage the operating system, applications, and data.
# *   **Streaming Services:** Watching movies and TV shows on Netflix, Spotify, or other streaming services.
# *   **Social Media:** Using Facebook, Twitter, Instagram, and other social media platforms.
# *   **Gaming:** Playing online games.
# *   **Data Analytics:** Processing and analyzing large amounts of data.
#
# **Benefits of Using the Cloud:**
#
# *   **Cost Savings:**  Often cheaper than buying and maintaining your own hardware and software.
# *   **Scalability:**  Easily scale resources up or down as needed.
# *   **Accessibility:** Access your data and applications from anywhere with an internet connection.
# *   **Reliability:**  Cloud providers typically have robust infrastructure and backup systems, making your data more reliable.
# *   **Collaboration:**  Easier to collaborate with others on documents and projects.
# *   **Automatic Updates:**  Cloud providers handle software updates and maintenance.
# *   **Security:** Cloud providers invest heavily in security measures to protect your data. (Though security breaches can still happen, of course).
#
# **Drawbacks of Using the Cloud:**
#
# *   **Internet Dependency:** You need an internet connection to access cloud services.
# *   **Security Risks:**  Data breaches and security vulnerabilities are a concern, although cloud providers invest heavily in security.
# *   **Vendor Lock-in:**  It can be difficult to switch cloud providers once you've committed to one.
# *   **Downtime:**  Cloud services can experience downtime, which can disrupt your work.
# *   **Control:** You have less direct control over the infrastructure than you would if you were managing your own servers.
# *   **Data Privacy:** Concerns about where your data is stored and who has access to it.
#
# **Different Types of Cloud Deployments:**
#
# *   **Public Cloud:**  Services are offered over the public internet and are available to anyone who wants to use them (e.g., Amazon Web Services (AWS), Google Cloud Platform (GCP), Microsoft Azure).
# *   **Private Cloud:**  Infrastructure is dedicated to a single organization.  It can be hosted on-site or by a third-party provider.
# *   **Hybrid Cloud:**  A combination of public and private clouds, allowing organizations to use the best of both worlds.
# *   **Community Cloud:** Shared infrastructure between several organizations with similar concerns (e.g., security requirements, compliance policies).
#
# **In Simple Terms:**
#
# The cloud is like renting computing resources (storage, processing power, software) from someone else instead of buying and maintaining them yourself.  It's a convenient, scalable, and often cost-effective way to store data, run applications, and access services over the internet.
#
# I hope this explanation helps!  Let me know if you have any other questions.

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

load_dotenv()

api_key = os.getenv("GOGLE_API_KEY")

genai.configure(api_key=api_key)

model = genai.GenerativeModel(model_name="gemini-1.5-flash")

user_prompt = "how to ride bike"

response = model.generate_content(user_prompt)

print(response.text)
# Out:
# Learning to ride a bike takes practice and patience, but it's a rewarding experience! Here's a step-by-step guide:
#
# **1. Get the Right Bike:**
#
# * **Size Matters:**  The bike should be the right size for you.  You should be able to comfortably stand over the top tube (the horizontal bar) with a few inches of clearance.  A bike that's too big or too small will make learning much harder.  Consider renting or borrowing a bike before buying one to ensure a good fit.
# * **Type of Bike:** A simpler bike without gears is best for learning.  Avoid bikes with complex components initially.
#
# **2. Find a Safe Place to Practice:**
#
# * **Level Ground:** Choose a flat, paved area with plenty of space, away from traffic and obstacles.  A park, empty parking lot, or quiet street are good options.
# * **Soft Surface (Optional):** Grass can be a gentler learning environment if you're worried about falls.
#
# **3. Getting Comfortable:**
#
# * **Adjust the Seat:** The seat should be high enough that you can comfortably reach the pedals with your legs slightly bent at the bottom of the stroke.
# * **Practice Balancing:**  Start by sitting on the bike and scooting along using your feet. Get a feel for how the bike balances.  Try lifting your feet for short periods to practice balancing.  This is crucial.
# * **Brakes:** Learn how the brakes work and practice using them gently.
#
# **4. Starting to Pedal:**
#
# * **Put Your Feet on the Pedals:** Place your feet on the pedals, one slightly ahead of the other (as if you are already pedaling).
# * **Push Off:** Use your feet to push off the ground and start moving slowly.
# * **Pedaling:** Once you're rolling, begin pedaling smoothly and consistently.
# * **Steering:** Practice gentle steering using the handlebars. Look ahead, not down at your feet.
# * **Balancing:** Maintain your balance by shifting your weight and making small adjustments with the handlebars.  This takes practice!
#
# **5. Practice and Patience:**
#
# * **Short Sessions:** Start with short practice sessions, perhaps 15-20 minutes at a time.  Don't get discouraged if you don't master it immediately.
# * **Rest Breaks:** Take breaks when needed.
# * **Be Persistent:** Keep practicing, even if you fall a few times.  It's all part of the learning process.
# * **Ask for Help:** If possible, have a friend or family member run alongside you for support, especially in the beginning.  They can help you stay balanced and give you encouragement.
#
# **6. Advanced Skills:**
#
# * **Turning:** Once you're comfortable pedaling in a straight line, practice turning.  Lean into the turn slightly, using your handlebars to guide the bike.
# * **Stopping:** Practice smooth stopping using the brakes.
# * **Starting and Stopping:** Practice starting and stopping smoothly and safely.
#
# **Important Safety Tips:**
#
# * **Wear a Helmet:** This is absolutely crucial to protect your head in case of a fall.
# * **Protective Gear:** Consider wearing knee pads and elbow pads, especially when starting out.
# * **Be Aware of Your Surroundings:** Pay attention to traffic and other obstacles.
#
# Remember, everyone learns at their own pace.  Don't compare yourself to others, and enjoy the process!  With consistent practice, you'll be riding your bike confidently in no time.
